# %%
import pandas as pd

df = pd.read_csv("./employee_data.csv")
df.head()  # First 5 rows
df.tail()  # Last 5 rows
df.sample(frac=0.1, random_state=67)  # Randomly any rows
print(df.columns)
print(df.index)
print(df.info(verbose=False))
# Out:
# Index(['employee_id', 'name', 'age', 'salary', 'department', 'position',
#        'project', 'years_in_company'],
#       dtype='object')
# RangeIndex(start=0, stop=100, step=1)
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Columns: 8 entries, employee_id to years_in_company
# dtypes: int64(4), object(4)
# memory usage: 6.4+ KB
# None

# %%
df.describe()  # Descriptive stats
df[["salary"]].describe()
print(df.shape)
print(len(df))
# Out:
# (100, 8)
# 100
#             name  salary
# 0     Employee_1   67940
# 1     Employee_2   95854
# 2     Employee_3  108293
# 3     Employee_4   55637
# 4     Employee_5   55284
# ..           ...     ...
# 95   Employee_96  149270
# 96   Employee_97   67508
# 97   Employee_98   86246
# 98   Employee_99   72260
# 99  Employee_100   77197
#
# [100 rows x 2 columns]

# %%
print(df["name"])  # Becomes a series
print(df["name", "salary"])  # Error ofc, series can't have multiple cols
print(df[["name", "salary"]]) # Multiple cols
df[df.columns[-5:]]
df[[c for c in df.columns if "salary" in c]]
df.select_dtypes("int")
# Out:
# 0       Employee_1
# 1       Employee_2
# 2       Employee_3
# 3       Employee_4
# 4       Employee_5
#           ...
# 95     Employee_96
# 96     Employee_97
# 97     Employee_98
# 98     Employee_99
# 99    Employee_100
# Name: name, Length: 100, dtype: object
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\jinma\JDev\Learn\ml\env\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:7088, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# ...
